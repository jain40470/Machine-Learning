# %% [markdown]
# # Random Variables
#
# - What are algebra variable
#
#    - In algebra a variable , like x , is an unknown value.
#    - Eg : x + 5 = 10 => x = 5
#    - Variable denoted by small letter.
#
# - What are random variables in Stats and Probability
#
#    - A random variable is a set of possible values from random experiment.
#    - Eg : Coin Toss (H/T) : X = {1,0} , Dice roll (1,2,3,4,5,6) : Y = {1,2,3,4,5,6}
#    - Variable denoted by capital letter.
#
# - Types of random variable
#
#    - Discrete Random Variable
#      - Eg : {H,T} , {1,2,3,4,5,6}
#
#    - Continous Random Variable
#      - Eg : Cgpa can be from 0 to 10 any interger.

# %% [markdown]
# # Probability Distribution
#
# - Probability distribution is a list of all the possible outcomes of a random variable along with their corresponding
#   probability values.
#
# - Example :
#
#    -  Coin Toss
#       - This table is called probability distribution
#
#       - ![Coin.png](attachment:Coin.png)
#
#    - Rolling a Dice
#       - This table is called probability distribution
#
#       - ![Dice.png](attachment:Dice.png)

# %% [markdown]
# - Problem with distribution
#
#   - In many scenarios , the numnber of outcomes can be much larger and hence a table would be tedious to write down.
#     In worst case , the number of possible outcomes could be infinite.
#     Eg : Rolling 10 dice together.
#
#   - Solution
#     - What if we use a mathematical function (i.e Probabilty Distribution Function) to model the relationship between outcome and probability.

# %% [markdown]
# - Type of Probability Distribution
#
#   - Since we are working with two type of random varibales i.e Discrete Random Variable , Continous Random Variable.
#
#   - ![TypePFunction.png](attachment:TypePFunction.png)
#
# - Famous Probability Distributions
#
#   - ![FamousPD.png](attachment:FamousPD.png)

# %% [markdown]
# - Why are Probability Distributions Important ?
#
#   - Gives an idea about the shape/distibution of the data.
#   - If our data follows a famous distribution then we automatically know a lot about the data.
#
# - Note on Parameters (In probability distribution function)
#
#   - You can think parameter as tuning nobs.
#   - Parameters in probability distributions are numerical values that determine the shape, location, and scale of the distribution.
#   - Different probability distributions have different sets of parameters that determine their shape and characteristics, and understanding these parameters is essential in statistical analysis and inference.

# %% [markdown]
# # Probability Distribution Functions
#
# - A probability distribution function (PDF) is a mathematical function that describes the probability of
#   obtaining different values of a random variable in a particular distribution function.
#
#   It is of two types
#
#   - Probability Mass Function (PMF)   (working with discrete random variable)
#
#   - Probability Density Function (PDF)  (working with continous random variable)
#
# - we can form Cumulative Distributive Function (CDF) using above .

# %% [markdown]
# # Probability Mass Function (PMF)
#
# - PMF stands for Probability Mass Function. It is a mathematical function that describes the probability distribution of a discrete random variable.
# - The PMF of a discrete random variable assigns a probability to each possible value of the random variable. The probabilities assigned by the PMF must satisfy two conditions
#     - The probability assigned to each value must be non-negative (i.e., greater than or equal to zero).
#     - The sum of the probabilities assigned to all possible values must equal 1.
#
#
# X axis : Value
#
# Y axis : Probability

# %%
import pandas as pd
import random
import numpy as np

# %% [markdown]
# Rolling one dice

# %%
L = []

for i in range(10000) : # rolling dics 10000 times
    L.append(random.randint(1,6))

a = pd.Series(L).value_counts()
b = pd.Series(L).value_counts().sum()
c = a/b

print(a)
print(b)
print(c)

c = c.sort_index()
print(c)

c.plot(kind = 'bar')

# btw it is uniform probability distribution
# Out:
# 3    1747
# 4    1711
# 6    1705
# 1    1633
# 2    1617
# 5    1587
# Name: count, dtype: int64
# 10000
# 3    0.1747
# 4    0.1711
# 6    0.1705
# 1    0.1633
# 2    0.1617
# 5    0.1587
# Name: count, dtype: float64
# 1    0.1633
# 2    0.1617
# 3    0.1747
# 4    0.1711
# 5    0.1587
# 6    0.1705
# Name: count, dtype: float64
# <Axes: >

# %% [markdown]
# Rolling two dice

# %%
L = []

for i in range(10000) : # rolling dics 10000 times
    a = random.randint(1,6)
    b = random.randint(1,6)
    L.append(a + b)

a = pd.Series(L).value_counts()
b = pd.Series(L).value_counts().sum()
c = a/b

print(a)
print(b)
print(c)

c = c.sort_index()
print(c)

c.plot(kind = 'bar')

# btw it is uniform probability distribution
# Out:
# 7     1656
# 8     1402
# 6     1387
# 5     1156
# 9     1134
# 4      851
# 10     805
# 3      538
# 11     522
# 12     282
# 2      267
# Name: count, dtype: int64
# 10000
# 7     0.1656
# 8     0.1402
# 6     0.1387
# 5     0.1156
# 9     0.1134
# 4     0.0851
# 10    0.0805
# 3     0.0538
# 11    0.0522
# 12    0.0282
# 2     0.0267
# Name: count, dtype: float64
# 2     0.0267
# 3     0.0538
# 4     0.0851
# 5     0.1156
# 6     0.1387
# 7     0.1656
# 8     0.1402
# 9     0.1134
# 10    0.0805
# 11    0.0522
# 12    0.0282
# Name: count, dtype: float64
# <Axes: >

# %% [markdown]
# # Cumulative Distribution Function(CDF) of PMF

# %% [markdown]
# The cumulative distribution function (CDF) F(x) desgribes the probability that a random variable X with a
# given probability distribution will be found at a value less than or equal to x.
#
# F(x) = P(X <= x)

# %%
L = []

for i in range(10000) : # rolling dics 10000 times
    a = random.randint(1,6)
    b = random.randint(1,6)
    L.append(a + b)

a = pd.Series(L).value_counts()
b = pd.Series(L).value_counts().sum()
c = a/b

print(a)
print(b)
print(c)

c = c.sort_index()
print(c)

c = np.cumsum(c)
print(c)

c.plot(kind = 'bar')
# Out:
# 7     1702
# 8     1397
# 6     1352
# 9     1141
# 5     1113
# 10     831
# 4      817
# 11     547
# 3      540
# 2      307
# 12     253
# Name: count, dtype: int64
# 10000
# 7     0.1702
# 8     0.1397
# 6     0.1352
# 9     0.1141
# 5     0.1113
# 10    0.0831
# 4     0.0817
# 11    0.0547
# 3     0.0540
# 2     0.0307
# 12    0.0253
# Name: count, dtype: float64
# 2     0.0307
# 3     0.0540
# 4     0.0817
# 5     0.1113
# 6     0.1352
# 7     0.1702
# 8     0.1397
# 9     0.1141
# 10    0.0831
# 11    0.0547
# 12    0.0253
# Name: count, dtype: float64
# 2     0.0307
# 3     0.0847
# 4     0.1664
# 5     0.2777
# 6     0.4129
# 7     0.5831
# 8     0.7228
# 9     0.8369
# 10    0.9200
# 11    0.9747
# 12    1.0000
# Name: count, dtype: float64
# <Axes: >

# %% [markdown]
# # Probability Density Function (PDF)

# %% [markdown]
# PDF stands for Probability Density Function.
# It is a mathematical function that describes the probability distribution of a continuous random variable.
#
# X-axis : Value
#
# Y-axis : Probability Density
#
# ![pdf.png](attachment:pdf.png)

# %% [markdown]
# - Why Probability Not on Y-axis?
#
#     - since x axis have infinite value then probability will be very close to 0.
#     - So we have Probability Density
#     - Probabiliy Density : Will give u this value , the probability of lying b/w two numbers.
#
# - What does the areas of this graph represents ?
#
#    - Like P( 0 <= x <= 10) , cut out that area , calculate it . This area will represnets the probability.
#
# - Example of Distribution
#
#    - Normal Distribution
#
#    - log-Normal Distribution
#
#    - Poisson Distribution
#
# - How is Graph Calculated
#
#    - Using Density Estimation

# %% [markdown]
# # Density Estimation
#
# - Density estimation is a statistical technique used to estimate the probability density function (PDF) of a random variable based on a set of observations or data.
#
# - In simpler terms, it involves estimating the underlying distribution of a set of data points.
#
# - Density estimation can be used for a variety of purposes, such as hypothesis testing, data analysis, and data visualization.
#
# - It is particularly useful in areas such as machine learning, where it is often used to estimate the probability distribution of input data or to model the likelihood of certain events or outcomes.
#
# - There are various methods for density estimation, including parametric and non-parametric approaches.
#
#     - Parametric methods assume that the data follows a specific probability distribution (such as a normal distribution)
#
#     - Non-parametric methods do not make any assumptions about the distribution and instead estimate it directly from the data.
#
# - Commonly used techniques for density estimation include kernel density estimation (KDE), histogram estimation, and Gaussian mixture models (GMMs).
#
# - The choice of method depends on the specific characteristics of the data and the intended use of the density estimate.

# %% [markdown]
# # Parametric Density Estimation
#
# - Parametric density estimation is a method of estimating the probability density function (PDF) of a random variable by assuming that the underlying distribution belongs to a specific parametric family of probability distributions, such as the normal, exponential, or Poisson distributions.
#
# - Example : like we plot a histogram , u find it something liek normal distribution , then u do furter thing considering that , and calculating its parametere from available data and then use the PDF equation of that distribution.

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import normal   # to generate data like normal distribution

# %%
sample = normal(loc = 50,scale=5,size=1000)
# loc   : mean
# scale : std deviation

# %%
print("Mean      : " , sample.mean())
print("Variance  : " , sample.var())
print("Std Devn. : " , sample.std())
# Out:
# Mean      :  49.91349681322857
# Variance  :  23.67663135608247
# Std Devn. :  4.865863885897598

# %%
# plot the histogram to understand the distribution of data.
plt.hist(sample , bins = 10)

# we find it something related to normal distribution , so calculating the required parameter to put in eqn.
# Out:
# (array([  2.,   5.,  34., 122., 232., 295., 204.,  84.,  18.,   4.]),
#  array([31.06838488, 34.61628037, 38.16417587, 41.71207136, 45.25996685,
#         48.80786235, 52.35575784, 55.90365334, 59.45154883, 62.99944432,
#         66.54733982]),
#  <BarContainer object of 10 artists>)

# %%
sample_mean = sample.mean()
sample_devn = sample.std()

# %%
from scipy.stats import norm
# SciPy is an open-source Python library used for scientific and technical computing. 
# It builds on NumPy and provides a large number of higher-level functions that operate on NumPy arrays

distribution = norm(sample_mean, sample_devn)

# %%
values = np.linspace(sample.min(),sample.max(),100)  # creating 100 intervales b/w min and max

# %%
probability_densities = [distribution.pdf(value) for value in values]

# %%
plt.hist(sample , bins = 10 , density=True) # density = True to make scale same
plt.plot(values , probability_densities)

# %%
import seaborn as sns
sns.distplot(sample)
# Out:
# /var/folders/68/g_j6jm596l5dg7k28vc763fh0000gn/T/ipykernel_3439/1482356190.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample)
# <Axes: ylabel='Density'>

# %% [markdown]
# # Non-Parametric Density Estimation (KDE)
